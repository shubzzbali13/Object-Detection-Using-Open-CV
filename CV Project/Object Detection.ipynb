# %%
# !pip install ultralytics -q
from matplotlib import pyplot as plt
import cv2
# !pip install -U kora
from kora.drive import upload_public

# %%
# !yolo detect predict model=yolov8m.pt source="/content/videoplayback.mp4"
# Out:
# Ultralytics YOLOv8.0.180 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8m summary (fused): 218 layers, 25886080 parameters, 0 gradients
#
# video 1/1 (1/1830) /content/videoplayback.mp4: 384x640 1 bird, 120.6ms
# video 1/1 (2/1830) /content/videoplayback.mp4: 384x640 1 teddy bear, 26.0ms
# video 1/1 (3/1830) /content/videoplayback.mp4: 384x640 1 bird, 25.9ms
# video 1/1 (4/1830) /content/videoplayback.mp4: 384x640 1 cat, 25.9ms
# video 1/1 (5/1830) /content/videoplayback.mp4: 384x640 1 cat, 1 bear, 26.0ms
# video 1/1 (6/1830) /content/videoplayback.mp4: 384x640 1 bird, 25.9ms
# video 1/1 (7/1830) /content/videoplayback.mp4: 384x640 1 bird, 23.1ms
# video 1/1 (8/1830) /content/videoplayback.mp4: 384x640 1 bird, 18.4ms
# video 1/1 (9/1830) /content/videoplayback.mp4: 384x640 1 bird, 18.5ms
# video 1/1 (10/1830) /content/videoplayback.mp4: 384x640 1 bird, 18.5ms
# video 1/1 (11/1830) /content/videoplayback.mp4: 384x640 1 dog, 18.4ms
# ...

# %%
# !ffmpeg -i {"/content/runs/detect/predict/videoplayback.avi"} -vcodec libx264 {"final.mp4"}
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
url = upload_public('final.mp4')
# then display it
from IPython.display import HTML
HTML(f"""<video src={url} width=500 controls/>""")
# Out:
# ...
# <video src=https://drive.google.com/uc?id=1bZvg-UEu_7A6N-IJqLlfnY0F14afycTE width=500 controls/>
